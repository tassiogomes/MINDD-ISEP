# %% [markdown]
# <a href="https://colab.research.google.com/github/tassiogomes/MINDD-ISEP/blob/main/MINDD_PL01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. View the loaded data.
import pandas as pd

df =  pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")

df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#2. Get information about the dataframe, such as the number of rows, number of columns, and column names.

print(df.describe())
print(df.shape)
# Get the number of rows and columns
num_rows, num_columns = df.shape # elements of array, first and second
print(f"Number of rows: {num_rows}")
print(df.columns) #retrieve index
print(df.columns.to_list()) #to_list make it better
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07
# (458, 9)
# Number of rows: 458
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')
# ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
#3. View only the variable names in this dataframe.
print(df.columns.to_list()) #variables names
# Out:
# ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
#4. What is the size of the data set?
df.size #number of elements
# Out:
# 4122

# %%
#5. Get statistics from the dataframe's numerical columns
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.head(5)
#df.tail(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#7. Select the College column
college_columns_df = df[["College"]] #two brackets return df
college_columns = df["College"]      #one bracket return Series
print(college_columns_df)
print(college_columns)
# Out:
#                College
# 0                Texas
# 1            Marquette
# 2    Boston University
# 3        Georgia State
# 4                  NaN
# ..                 ...
# 453             Butler
# 454                NaN
# 455                NaN
# 456             Kansas
# 457                NaN
#
# [458 rows x 1 columns]
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
#              ...
# 453               Butler
# 454                  NaN
# 455                  NaN
# 456               Kansas
# 457                  NaN
# Name: College, Length: 458, dtype: object

# %%
#8. Select columns Name, Position, College, and rows 15 to 20
selected_data = df.loc[15:20, ["Name", "Position", "College"]]
selected_data = df[["Name", "Position", "College"]][15:20 ]

print(selected_data)
# Out:
#                        Name Position         College
# 15         Bojan Bogdanovic       SG             NaN
# 16             Markel Brown       SG  Oklahoma State
# 17          Wayne Ellington       SG  North Carolina
# 18  Rondae Hollis-Jefferson       SG         Arizona
# 19             Jarrett Jack       PG    Georgia Tech

# %%
# 9. View all players from Position = ‘PF’.
#player_pf = df["Position"] == "PF" #retrieve column position with true or false
player_pf_serie = df['Position'] == 'PF' #retrieve Series with True or False (one bracket)
player_pf = df[df['Position'] == 'PF'] #retrieve df with PF condition returning all columns
player_pf_filtered = df[df['Position'] == 'PF'][['Position', 'Name']]# return filtered columns

print(player_pf_serie)
print(player_pf)
print(player_pf_filtered)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Name: Position, Length: 458, dtype: bool
#                  Name                    Team  Number Position   Age Height  \
# 4       Jonas Jerebko          Boston Celtics     8.0       PF  29.0   6-10
# 5        Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# 6       Jordan Mickey          Boston Celtics    55.0       PF  21.0    6-8
# 24   Chris McCullough           Brooklyn Nets     1.0       PF  21.0   6-11
# 25        Willie Reed           Brooklyn Nets    33.0       PF  26.0   6-10
# ..                ...                     ...     ...      ...   ...    ...
# 435    Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0    7-1
# 441       Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0    6-9
# 442     Trevor Booker               Utah Jazz    33.0       PF  28.0    6-8
# ...

# %%
# 10. View all distinct values from the Team column, and their numbers.
team_counts = df[['Team']].value_counts() # value_counts() return distinct values
team_counts
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Atlanta Hawks             15
# Utah Jazz                 15
# Toronto Raptors           15
# San Antonio Spurs         15
# Sacramento Kings          15
# Portland Trail Blazers    15
# Phoenix Suns              15
# Philadelphia 76ers        15
# Oklahoma City Thunder     15
# Boston Celtics            15
# Miami Heat                15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Indiana Pacers            15
# Houston Rockets           15
# Golden State Warriors     15
# Detroit Pistons           15
# Denver Nuggets            15
# Dallas Mavericks          15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Charlotte Hornets         15
# Brooklyn Nets             15
# Washington Wizards        15
# Minnesota Timberwolves    14
# Orlando Magic             14
# dtype: int64

# %%
# 11. View players from Team = Los Angeles Lakers (all columns except Team).
players = df[df["Team"] == "Los Angeles Lakers"].drop(columns=['Team'])
players
# Out:
#                   Name  Number Position   Age Height  Weight     College  \
# 106       Brandon Bass     2.0       PF  31.0    6-8   250.0         LSU
# 107        Tarik Black    28.0        C  24.0    6-9   250.0      Kansas
# 108      Anthony Brown     3.0       SF  23.0    6-7   210.0    Stanford
# 109        Kobe Bryant    24.0       SF  37.0    6-6   212.0         NaN
# 110    Jordan Clarkson     6.0       PG  24.0    6-5   194.0    Missouri
# 111        Roy Hibbert    17.0        C  29.0    7-2   270.0  Georgetown
# 112    Marcelo Huertas     9.0       PG  33.0    6-3   200.0         NaN
# 113         Ryan Kelly     4.0       PF  25.0   6-11   230.0        Duke
# 114    Larry Nance Jr.     7.0       PF  23.0    6-9   230.0     Wyoming
# 115      Julius Randle    30.0       PF  21.0    6-9   250.0    Kentucky
# 116   D'Angelo Russell     1.0       PG  20.0    6-5   195.0  Ohio State
# 117       Robert Sacre    50.0        C  27.0    7-0   270.0     Gonzaga
# ...

# %%
# 12. View the data in reverse alphabetical order of College and decreasing Age.
reversed_data = df.sort_values(by = ['College', 'Age'], ascending =[False, False])
reversed_data
# Out:
#                    Name                Team  Number Position   Age Height  \
# 308          David West   San Antonio Spurs    30.0       PF  35.0    6-9
# 114     Larry Nance Jr.  Los Angeles Lakers     7.0       PF  23.0    6-9
# 231        Devin Harris    Dallas Mavericks    34.0       PG  33.0    6-3
# 129           Jon Leuer        Phoenix Suns    30.0       PF  27.0   6-10
# 145          Duje Dukan    Sacramento Kings    26.0       PF  24.0    6-9
# ..                  ...                 ...     ...      ...   ...    ...
# 40   Kristaps Porzingis     New York Knicks     6.0       PF  20.0    7-3
# 62        Bruno Caboclo     Toronto Raptors    20.0       SF  20.0    6-9
# 393     Emmanuel Mudiay      Denver Nuggets     0.0       PG  20.0    6-5
# 445          Dante Exum           Utah Jazz    11.0       PG  20.0    6-6
# 457                 NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight    College     Salary
# 308   250.0     Xavier  1499187.0
# ...

# %%
# 13. View the data in descending order of salary
sorted_values = df.sort_values(by=["Salary"], ascending=[False])
sorted_values
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 350    Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397     Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College      Salary
# ...

# %%
# 14. Make a salary histogram.
df.hist(column="Salary", bins=35, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)
# Out:
# array([[<Axes: title={'center': 'Salary'}>]], dtype=object)

# %%
# 15. Make an age boxplot.
df.boxplot(column=("Salary"))
# Out:
# <Axes: >

# %%
# 16. Make a salary vs. age plot.
df[['Salary', 'Age']].boxplot(vert=True)
# Out:
# <Axes: >

# %%
# 17. View the age and average salary of the players.
average_salary_by_age = df.groupby('Age')['Salary'].mean().round(2).reset_index() #reset_index puts new index to df

# Rename the columns for clarity
average_salary_by_age.columns = ['Age', 'Average Salary']

average_salary_by_age
# Out:
#      Age  Average Salary
# 0   19.0      1930440.00
# 1   20.0      2725790.84
# 2   21.0      2067379.63
# 3   22.0      2357963.46
# 4   23.0      2034746.23
# 5   24.0      3785300.31
# 6   25.0      3930867.41
# 7   26.0      6866566.25
# 8   27.0      6676741.18
# 9   28.0      5110188.60
# 10  29.0      6224177.00
# 11  30.0      7061858.57
# 12  31.0      8511396.55
# 13  32.0      7716958.15
# 14  33.0      3930739.00
# 15  34.0      7606030.00
# 16  35.0      3461739.75
# 17  36.0      2238119.60
# 18  37.0     12777778.00
# 19  38.0      1840041.00
# 20  39.0      2517872.50
# 21  40.0      4666916.67

# %%
#18. Present players for whom the age is lower than average and the salary is higher than average.
#players = df[['Age'] < df['Age'].mean() & (df['Salary'] > df['Salary'].mean())]
players = df[(df['Age'] < df['Age'].mean()) & (df['Salary'] > df['Salary'].mean())]
players = players[['Name', 'Age', 'Salary']] #showing just 3 columns
print(players)
# Out:
#                        Name   Age      Salary
# 0             Avery Bradley  25.0   7730337.0
# 1               Jae Crowder  25.0   6796117.0
# 64            DeMar DeRozan  26.0  10050000.0
# 66              Cory Joseph  24.0   7000000.0
# 82           Draymond Green  26.0  14260870.0
# 89            Klay Thompson  26.0  15501000.0
# 116        D'Angelo Russell  20.0   5103120.0
# 121            Eric Bledsoe  26.0  13500000.0
# 127          Brandon Knight  24.0  13500000.0
# 143        DeMarcus Cousins  25.0  15851950.0
# 153            Jimmy Butler  26.0  16407500.0
# 160          Nikola Mirotic  25.0   5543725.0
# 168            Kyrie Irving  24.0  16407501.0
# 177           Iman Shumpert  25.0   8988765.0
# 179        Tristan Thompson  25.0  14260870.0
# 189           Tobias Harris  23.0  16000000.0
# 191          Reggie Jackson  26.0  13913044.0
# 194           Marcus Morris  26.0   5000000.0
# 199             Paul George  26.0  17120106.0
# ...

# %%
#19. Get the salary variable statistics grouped by team.
df.groupby('Team')[['Salary']].describe()
# Out:
#                        Salary                                         \
#                         count          mean           std        min
# Team
# Atlanta Hawks            15.0  4.860197e+06  5.194508e+06   525093.0
# Boston Celtics           14.0  4.181505e+06  3.146033e+06  1148640.0
# Brooklyn Nets            15.0  3.501898e+06  5.317817e+06   134215.0
# Charlotte Hornets        15.0  5.222728e+06  4.538601e+06   189455.0
# Chicago Bulls            15.0  5.785559e+06  6.251088e+06   525093.0
# Cleveland Cavaliers      14.0  7.642049e+06  7.730329e+06   111196.0
# Dallas Mavericks         15.0  4.746582e+06  5.030279e+06   525093.0
# Denver Nuggets           14.0  4.294424e+06  4.320214e+06   258489.0
# Detroit Pistons          15.0  4.477884e+06  4.668478e+06   111444.0
# Golden State Warriors    15.0  5.924600e+06  5.664282e+06   289755.0
# Houston Rockets          15.0  5.018868e+06  6.414749e+06   200600.0
# ...

# %%
# 20. Make a boxplot of salary vs. Team

boxplot = df.boxplot(column='Salary', by='Team', vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
# Personalize os rótulos do eixo x e o título
boxplot.set_xlabel('Salary')
boxplot.set_title('Box Plot of Salary by Team')
# Out:
# Text(0.5, 1.0, 'Box Plot of Salary by Team')

# %%
#21 average salary per position
average_salary_per_position = df.groupby('Position')['Salary'].mean().round(2).reset_index()
average_salary_per_position.columns = ['Position', 'Average Salary'] #.columns
average_salary_per_position = average_salary_per_position[['Position', 'Average Salary']] # change columns directly
print(average_salary_per_position)
# Out:
#   Position  Average Salary
# 0        C      5967052.00
# 1       PF      4562482.99
# 2       PG      5077829.22
# 3       SF      4857392.57
# 4       SG      4009861.19

# %%
#22. Make a boxplot of salary vs. Position
boxplot = df.boxplot(column='Salary', by='Position', vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))

# Personalize os rótulos do eixo x e o título
boxplot.set_xlabel('Salary')
boxplot.set_title('Box Plot of Salary by Position')
# Out:
# Text(0.5, 1.0, 'Box Plot of Salary by Position')

# %%
#23. Get the statistics of the Age variable grouped by Position
age_describe_by_position = df.groupby('Position')['Age'].describe()
age_describe_by_position
# Out:
#           count       mean       std   min   25%   50%    75%   max
# Position
# C          78.0  27.371795  4.156388  20.0  24.0  27.0  30.00  40.0
# PF        100.0  27.160000  4.607241  20.0  24.0  27.0  30.00  40.0
# PG         92.0  26.847826  4.169314  20.0  24.0  26.5  30.00  40.0
# SF         85.0  26.858824  4.386540  20.0  23.0  26.0  29.00  38.0
# SG        102.0  26.539216  4.643043  19.0  23.0  25.0  29.75  39.0

# %%
#24. Count number of Nas per column

missing_values_per_column = df.isnull().sum()# Count NaN values per column
missing_values_college = df.groupby('College').size() - df.groupby('College')['College'].count().sort_values(ascending=False)

print(missing_values_per_column)
print("--------- missing_values_college -------")
print(missing_values_college)
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64
# --------- missing_values_college -------
# College
# Alabama             0
# Arizona             0
# Arizona State       0
# Arkansas            0
# Baylor              0
#                    ..
# Western Michigan    0
# Wichita State       0
# Wisconsin           0
# Wyoming             0
# Xavier              0
# Length: 118, dtype: int64

# %%
# 25. Remove line with Name, Team, Number, Position, Age, Height, Weight: NaN

df_cleaned = df.dropna(subset=['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight'])
df_cleaned
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# 26. Presents for each dateFrame column the number of NAs and their percentage

nan_counts = df.isna().sum() # Count NaN values per column

nan_percentages = (nan_counts / len(df)) * 100

nan_info = pd.DataFrame({'NaN Count': nan_counts, 'NaN Percentage': nan_percentages}) # Create a new DataFrame to present the results
print(nan_info)
# Out:
#           NaN Count  NaN Percentage
# Name              1        0.218341
# Team              1        0.218341
# Number            1        0.218341
# Position          1        0.218341
# Age               1        0.218341
# Height            1        0.218341
# Weight            1        0.218341
# College          85       18.558952
# Salary           12        2.620087

# %%
# 27. Fill in College column NaN values with 'no College'
df['College'].fillna('no College', inplace=True)
print(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# 28. View rows where "Salary" column has NaN values
rows_with_nan_salary = df[df['Salary'].isna()]

print(rows_with_nan_salary)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %%
# 29. Fill in the salary NaN values with the average salary value of the respective Team/Position
average_salary_by_team_position = df.groupby(['Team', 'Position'])['Salary'].mean().rename('Average_Salary').reset_index()
df['Salary'].fillna(average_salary_by_team_position['Average_Salary'], inplace=True)
print(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# 30. Count the number of Nas throughout all the dataframe
#all_nan_df = df.isnull().sum()
all_nan_df = df.isnull().sum().sum()
print(all_nan_df)
# Out:
# 17

# %%
# 31. Save the dataframe in a csv file and an excel file.
df.to_csv('data.csv', index=False)  # 'data.csv' is the desired CSV filename
